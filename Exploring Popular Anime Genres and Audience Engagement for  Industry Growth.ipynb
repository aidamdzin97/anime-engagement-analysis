# %%
#import phyton modules

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#loading datasets

anime_df = pd.read_csv("anime-dataset-2023.csv")

# %%
#Exploring data for anime dataset

anime_df.head()
# Out:
#    anime_id                             Name             English name  \
# 0         1                     Cowboy Bebop             Cowboy Bebop
# 1         5  Cowboy Bebop: Tengoku no Tobira  Cowboy Bebop: The Movie
# 2         6                           Trigun                   Trigun
# 3         7               Witch Hunter Robin       Witch Hunter Robin
# 4         8                   Bouken Ou Beet   Beet the Vandel Buster
#
#                          Other name Score  \
# 0                         カウボーイビバップ  8.75
# 1                    カウボーイビバップ 天国の扉  8.38
# 2                             トライガン  8.22
# 3  Witch Hunter ROBIN (ウイッチハンターロビン)  7.25
# 4                            冒険王ビィト  6.94
#
#                                  Genres  \
# 0         Action, Award Winning, Sci-Fi
# 1                        Action, Sci-Fi
# 2             Action, Adventure, Sci-Fi
# 3  Action, Drama, Mystery, Supernatural
# 4      Adventure, Fantasy, Supernatural
#
# ...

# %%
#Check the shape of datasets

print(f"Anime Dataset contains {anime_df.shape[0]} rows and {anime_df.shape[1]}columns.")
# Out:
# Anime Dataset contains 24905 rows and 24columns.

# %%
#Identify missing values using .info

anime_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 24905 entries, 0 to 24904
# Data columns (total 24 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   anime_id      24905 non-null  int64
#  1   Name          24905 non-null  object
#  2   English name  24905 non-null  object
#  3   Other name    24905 non-null  object
#  4   Score         24905 non-null  object
#  5   Genres        24905 non-null  object
#  6   Synopsis      24905 non-null  object
#  7   Type          24905 non-null  object
#  8   Episodes      24905 non-null  object
#  9   Aired         24905 non-null  object
#  10  Premiered     24905 non-null  object
#  11  Status        24905 non-null  object
#  12  Producers     24905 non-null  object
#  13  Licensors     24905 non-null  object
#  14  Studios       24905 non-null  object
#  15  Source        24905 non-null  object
#  16  Duration      24905 non-null  object
#  17  Rating        24905 non-null  object
# ...

# %%
#Identify missing values using isnull()
print("Missing Values Count:\n", anime_df.isnull().sum())

# Display rows with missing values
anime_df[anime_df.isnull().any(axis=1)]
# Out:
# Missing Values Count:
#  anime_id        0
# Name            0
# English name    0
# Other name      0
# Score           0
# Genres          0
# Synopsis        0
# Type            0
# Episodes        0
# Aired           0
# Premiered       0
# Status          0
# Producers       0
# Licensors       0
# Studios         0
# Source          0
# Duration        0
# Rating          0
# Rank            0
# Popularity      0
# Favorites       0
# Scored By       0
# Members         0
# Image URL       0
# dtype: int64
# Empty DataFrame
# Columns: [anime_id, Name, English name, Other name, Score, Genres, Synopsis, Type, Episodes, Aired, Premiered, Status, Producers, Licensors, Studios, Source, Duration, Rating, Rank, Popularity, Favorites, Scored By, Members, Image URL]
# Index: []
#
# [0 rows x 24 columns]

# %%
#Save new variable as cleaned_anime_df and cleaned_user_filtered_df

cleaned_anime_df = anime_df

# %%
#Check for duplicates

duplicates_anime = cleaned_anime_df.duplicated().sum()
print(f"Number of duplicate rows: {duplicates_anime}")

#Display duplicate rows if any exist

if duplicates_anime > 0:
    print("Duplicate rows found:")
    display(cleaned_anime_df[cleaned_anime_df.duplicated(keep=False)]) # Show all duplicate rows (including first occurrence)

# Remove duplicates if necessary

cleaned_anime_df = cleaned_anime_df.drop_duplicates()

# Verify removal

print(f"Number of duplicate rows after removal:{cleaned_anime_df.duplicated().sum()}")
# Out:
# Number of duplicate rows: 0
# Number of duplicate rows after removal:0

# %%
# Export data frame into CSV

cleaned_anime_df.to_csv('cleaned_anime_df.csv', index=False)

# %%
#cleaned_anime_df['Premiered'].head() to see specific column values

cleaned_anime_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 24905 entries, 0 to 24904
# Data columns (total 49 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   anime_id                24905 non-null  int64
#  1   Name                    24905 non-null  object
#  2   English name            24905 non-null  object
#  3   Other name              24905 non-null  object
#  4   Score                   24905 non-null  object
#  5   Genres                  24905 non-null  object
#  6   Synopsis                24905 non-null  object
#  7   Type                    24905 non-null  object
#  8   Episodes                24905 non-null  object
#  9   Aired                   24905 non-null  object
#  10  Premiered               24905 non-null  object
#  11  Status                  24905 non-null  object
#  12  Producers               24905 non-null  object
#  13  Licensors               24905 non-null  object
# ...

# %%
anime_filter_df = pd.read_csv("anime-filtered.csv")

# %%
anime_filter_df.head()
# Out:
#    anime_id                             Name  Score  \
# 0         1                     Cowboy Bebop   8.78
# 1         5  Cowboy Bebop: Tengoku no Tobira   8.39
# 2         6                           Trigun   8.24
# 3         7               Witch Hunter Robin   7.27
# 4         8                   Bouken Ou Beet   6.98
#
#                                               Genres            English name  \
# 0    Action, Adventure, Comedy, Drama, Sci-Fi, Space            Cowboy Bebop
# 1              Action, Drama, Mystery, Sci-Fi, Space  Cowboy Bebop:The Movie
# 2  Action, Sci-Fi, Adventure, Comedy, Drama, Shounen                  Trigun
# 3  Action, Mystery, Police, Supernatural, Drama, ...      Witch Hunter Robin
# 4          Adventure, Fantasy, Shounen, Supernatural  Beet the Vandel Buster
#
#                       Japanese name  \
# 0                         カウボーイビバップ
# 1                    カウボーイビバップ 天国の扉
# 2                             トライガン
# ...

# %%
print(f"Anime Filter contains {anime_filter_df.shape[0]} rows and {anime_filter_df.shape[1]}columns.")
# Out:
# Anime Filter contains 14952 rows and 25columns.

# %%
#Identify missing values using .info

anime_filter_df.info(memory_usage='deep', show_counts=True)
#missing value sypnopsis(obj), Ranked(float)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14952 entries, 0 to 14951
# Data columns (total 25 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   anime_id       14952 non-null  int64
#  1   Name           14952 non-null  object
#  2   Score          14952 non-null  float64
#  3   Genres         14952 non-null  object
#  4   English name   14952 non-null  object
#  5   Japanese name  14952 non-null  object
#  6   sypnopsis      13602 non-null  object
#  7   Type           14952 non-null  object
#  8   Episodes       14952 non-null  object
#  9   Aired          14952 non-null  object
#  10  Premiered      14952 non-null  object
#  11  Producers      14952 non-null  object
#  12  Licensors      14952 non-null  object
#  13  Studios        14952 non-null  object
#  14  Source         14952 non-null  object
#  15  Duration       14952 non-null  object
#  16  Rating         14952 non-null  object
# ...

# %%
#Identify missing values using isnull()
print("Missing Values Count:\n", anime_filter_df.isnull().sum())

# Display rows with missing values
anime_filter_df[anime_filter_df.isnull().any(axis=1)]
# Out:
# Missing Values Count:
#  anime_id            0
# Name                0
# Score               0
# Genres              0
# English name        0
# Japanese name       0
# sypnopsis        1350
# Type                0
# Episodes            0
# Aired               0
# Premiered           0
# Producers           0
# Licensors           0
# Studios             0
# Source              0
# Duration            0
# Rating              0
# Ranked           1721
# Popularity          0
# Members             0
# Favorites           0
# Watching            0
# Completed           0
# On-Hold             0
# Dropped             0
# dtype: int64
#        anime_id                             Name  Score  \
# 165         188                    Gosenzo San'e   6.11
# 180         203                      Words Worth   6.75
# 188         211                        Pure Mail   6.26
# 190         213           Pia Carrot e Youkoso!!   6.02
# 191         214         Pia Carrot e Youkoso!! 2   6.15
# ...

# %%
#Remove rows with missing values in the synopsis and Ranked . Save this as a new variable called cleaned_anime_filter_df

cleaned_anime_filter_df = anime_filter_df.dropna(subset=['sypnopsis', 'Ranked'])

#Verify if the process was completed by checking the number of remaining missing values

print("Missing values after cleaning:")
print(cleaned_anime_filter_df.isnull().sum())
# Out:
# Missing values after cleaning:
# anime_id         0
# Name             0
# Score            0
# Genres           0
# English name     0
# Japanese name    0
# sypnopsis        0
# Type             0
# Episodes         0
# Aired            0
# Premiered        0
# Producers        0
# Licensors        0
# Studios          0
# Source           0
# Duration         0
# Rating           0
# Ranked           0
# Popularity       0
# Members          0
# Favorites        0
# Watching         0
# Completed        0
# On-Hold          0
# Dropped          0
# dtype: int64

# %%
#Check for duplicates

duplicates_anime_filter = cleaned_anime_filter_df.duplicated().sum()
print(f"Number of duplicate rows: {duplicates_anime_filter}")

#Display duplicate rows if any exist

if duplicates_anime_filter > 0:
    print("Duplicate rows found:")
    display(cleaned_anime_filter_df[cleaned_anime_filter_df.duplicated(keep=False)]) # Show all duplicate rows (including first occurrence)

# Remove duplicates if necessary

cleaned_anime_filter_df = cleaned_anime_filter_df.drop_duplicates()

# Verify removal

print(f"Number of duplicate rows after removal:{cleaned_anime_filter_df.duplicated().sum()}")
# Out:
# Number of duplicate rows: 0
# Number of duplicate rows after removal:0

# %%
cleaned_anime_filter_df.to_csv('cleaned_anime_filter_df.csv', index=False)

# %%
anime_final_df = pd.read_csv("final_animedataset.csv")

# %%
anime_final_df.head()
# Out:
#    username  anime_id  my_score  user_id  gender          title type source  \
# 0  karthiga        21         9  2255153  Female      One Piece   TV  Manga
# 1  karthiga        59         7  2255153  Female        Chobits   TV  Manga
# 2  karthiga        74         7  2255153  Female   Gakuen Alice   TV  Manga
# 3  karthiga       120         7  2255153  Female  Fruits Basket   TV  Manga
# 4  karthiga       178         7  2255153  Female   Ultra Maniac   TV  Manga
#
#    score  scored_by    rank  popularity  \
# 0   8.54     423868    91.0          35
# 1   7.53     175388  1546.0         188
# 2   7.77      33244   941.0        1291
# 3   7.77     167968   939.0         222
# 4   7.26       9663  2594.0        2490
#
#                                                genre
# 0  Action, Adventure, Comedy, Super Power, Drama,...
# 1      Sci-Fi, Comedy, Drama, Romance, Ecchi, Seinen
# 2                Comedy, School, Shoujo, Super Power
# ...

# %%
print(f"Anime Final Dataset contains {anime_final_df.shape[0]} rows and {anime_final_df.shape[1]}columns.")
# Out:
# Anime Final Dataset contains 35305695 rows and 13columns.

# %%
#Identify missing values using .info

anime_final_df.info(memory_usage='deep', show_counts=True)
#missing value username(obj), rank(float), popularity(int), genre(obj)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 35305695 entries, 0 to 35305694
# Data columns (total 13 columns):
#  #   Column      Non-Null Count     Dtype
# ---  ------      --------------     -----
#  0   username    35305439 non-null  object
#  1   anime_id    35305695 non-null  int64
#  2   my_score    35305695 non-null  int64
#  3   user_id     35305695 non-null  int64
#  4   gender      35305695 non-null  object
#  5   title       35305695 non-null  object
#  6   type        35305695 non-null  object
#  7   source      35305695 non-null  object
#  8   score       35305695 non-null  float64
#  9   scored_by   35305695 non-null  int64
#  10  rank        34553725 non-null  float64
#  11  popularity  35305695 non-null  int64
#  12  genre       35303428 non-null  object
# dtypes: float64(2), int64(5), object(6)
# memory usage: 14.3 GB

# %%
#Identify missing values using isnull()
print("Missing Values Count:\n", anime_final_df.isnull().sum())

# Display rows with missing values
anime_final_df[anime_final_df.isnull().any(axis=1)]
# Out:
# Missing Values Count:
#  username         256
# anime_id           0
# my_score           0
# user_id            0
# gender             0
# title              0
# type               0
# source             0
# score              0
# scored_by          0
# rank          751970
# popularity         0
# genre           2267
# dtype: int64
#                   username  anime_id  my_score  user_id  gender  \
# 138       RedvelvetDaisuki       320         0  1897606  Female
# 184       RedvelvetDaisuki       724         6  1897606  Female
# 186       RedvelvetDaisuki       741         0  1897606  Female
# 187       RedvelvetDaisuki       746         6  1897606  Female
# 188       RedvelvetDaisuki       747         0  1897606  Female
# ...                    ...       ...       ...      ...     ...
# 35305689     Joshua_Parris      3107         3  5772165    Male
# 35305690   Destoria-LeVaun      3250        10   266038  Female
# ...

# %%
#Remove rows with missing values in the synopsis and Ranked . Save this as a new variable called cleaned_anime_filter_df

cleaned_anime_final_df = anime_final_df.dropna(subset=['username', 'rank', 'genre'])

#Verify if the process was completed by checking the number of remaining missing values

print("Missing values after cleaning:")
print(cleaned_anime_final_df.isnull().sum())
# Out:
# Missing values after cleaning:
# username      0
# anime_id      0
# my_score      0
# user_id       0
# gender        0
# title         0
# type          0
# source        0
# score         0
# scored_by     0
# rank          0
# popularity    0
# genre         0
# dtype: int64

# %%
#Check for duplicates

duplicates_anime_final = cleaned_anime_final_df.duplicated().sum()
print(f"Number of duplicate rows: {duplicates_anime_final}")

#Display duplicate rows if any exist

if duplicates_anime_final > 0:
    print("Duplicate rows found:")
    display(cleaned_anime_final_df[cleaned_anime_final_df.duplicated(keep=False)]) # Show all duplicate rows (including first occurrence)

# Remove duplicates if necessary

cleaned_anime_final_df = cleaned_anime_final_df.drop_duplicates()

# Verify removal

print(f"Number of duplicate rows after removal:{cleaned_anime_final_df.duplicated().sum()}")
# Out:
# Number of duplicate rows: 0
# Number of duplicate rows after removal:0

# %%
cleaned_anime_final_df.to_csv('cleaned_anime_final_df.csv', index=False)

# %%
user_filtered_df = pd.read_csv("user-filtered.csv")

# %%
user_filtered_df.head()
# Out:
#    user_id  anime_id  rating
# 0        0        67       9
# 1        0      6702       7
# 2        0       242      10
# 3        0      4898       0
# 4        0        21      10

# %%
print(f"User Filtered Dataset contains {user_filtered_df.shape[0]} rows and {user_filtered_df.shape[1]}columns.")
# Out:
# User Filtered Dataset contains 109224747 rows and 3columns.

# %%
#Identify missing values using .info

user_filtered_df.info(memory_usage='deep', show_counts=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 109224747 entries, 0 to 109224746
# Data columns (total 3 columns):
#  #   Column    Non-Null Count      Dtype
# ---  ------    --------------      -----
#  0   user_id   109224747 non-null  int64
#  1   anime_id  109224747 non-null  int64
#  2   rating    109224747 non-null  int64
# dtypes: int64(3)
# memory usage: 2.4 GB

# %%
#Identify missing values using isnull()
print("Missing Values Count:\n", user_filtered_df.isnull().sum())

# Display rows with missing values
user_filtered_df[user_filtered_df.isnull().any(axis=1)]
# Out:
# Missing Values Count:
#  user_id     0
# anime_id    0
# rating      0
# dtype: int64
# Empty DataFrame
# Columns: [user_id, anime_id, rating]
# Index: []

# %%
cleaned_user_filtered_df = user_filtered_df
cleaned_user_filtered_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 109224747 entries, 0 to 109224746
# Data columns (total 3 columns):
#  #   Column    Dtype
# ---  ------    -----
#  0   user_id   int64
#  1   anime_id  int64
#  2   rating    int64
# dtypes: int64(3)
# memory usage: 2.4 GB

# %%
#Check for duplicates

duplicates_user_filtered = cleaned_user_filtered_df.duplicated().sum()
print(f"Number of duplicate rows: {duplicates_user_filtered}")

#Display duplicate rows if any exist

if duplicates_user_filtered > 0:
    print("Duplicate rows found:")
    display(cleaned_user_filtered_df[cleaned_user_filtered_df.duplicated(keep=False)]) # Show all duplicate rows (including first occurrence)

# Remove duplicates if necessary

cleaned_user_filtered_df = cleaned_user_filtered_df.drop_duplicates()

# Verify removal

print(f"Number of duplicate rows after removal:{cleaned_user_filtered_df.duplicated().sum()}")
# Out:
# Number of duplicate rows: 1
# Duplicate rows found:
#           user_id  anime_id  rating
# 19162032    61960     17549       0
# 19162033    61960     17549       0
# Number of duplicate rows after removal:0

# %%
cleaned_user_filtered_df.to_csv('cleaned_user_filtered_df.csv', index=False)

# %%
user_details_df = pd.read_csv("users-details-2023.csv")

# %%
print(f"User Details Dataset contains {user_details_df.shape[0]} rows and {user_details_df.shape[1]}columns.")
# Out:
# User Details Dataset contains 731290 rows and 16columns.

# %%
#Identify missing values using .info

user_details_df.info(memory_usage='deep', show_counts=True)
#missing value Username(obj), Gender(obj), Birthday(obj), Location(obj), Days Watched(float), Mean Score(float),
#Watching(float),Completed(float), On Hold(float), Dropped(float),Plan to Watch(float), Total Entries(float), Rewatched(float),
#Episodes Watched(float)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 731290 entries, 0 to 731289
# Data columns (total 16 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   Mal ID            731290 non-null  int64
#  1   Username          731289 non-null  object
#  2   Gender            224383 non-null  object
#  3   Birthday          168068 non-null  object
#  4   Location          152805 non-null  object
#  5   Joined            731290 non-null  object
#  6   Days Watched      731282 non-null  float64
#  7   Mean Score        731282 non-null  float64
#  8   Watching          731282 non-null  float64
#  9   Completed         731282 non-null  float64
#  10  On Hold           731282 non-null  float64
#  11  Dropped           731282 non-null  float64
#  12  Plan to Watch     731282 non-null  float64
#  13  Total Entries     731282 non-null  float64
#  14  Rewatched         731282 non-null  float64
# ...

# %%
#Identify missing values using isnull()
print("Missing Values Count:\n", user_details_df.isnull().sum())

# Display rows with missing values
user_details_df[user_details_df.isnull().any(axis=1)]
# Out:
# Missing Values Count:
#  Mal ID                   0
# Username                 1
# Gender              506907
# Birthday            563222
# Location            578485
# Joined                   0
# Days Watched             8
# Mean Score               8
# Watching                 8
# Completed                8
# On Hold                  8
# Dropped                  8
# Plan to Watch            8
# Total Entries            8
# Rewatched                8
# Episodes Watched         8
# dtype: int64
#          Mal ID    Username  Gender                   Birthday  \
# 1             3     Aokaado    Male                        NaN
# 2             4     Crystal  Female                        NaN
# 3             9      Arcane     NaN                        NaN
# 4            18         Mad     NaN                        NaN
# 6            23       Amuro     NaN  1988-02-22T00:00:00+00:00
# ...         ...         ...     ...                        ...
# ...

# %%
#Remove rows with missing values in the synopsis and Ranked . Save this as a new variable called cleaned_anime_filter_df

cleaned_user_details_df = user_details_df.dropna(subset=[
    'Username', 'Gender', 'Birthday', 'Location', 'Days Watched', 'Mean Score',
    'Watching', 'Completed', 'On Hold', 'Dropped', 'Plan to Watch', 'Total Entries', 'Rewatched', 'Episodes Watched'
])

#Verify if the process was completed by checking the number of remaining missing values

print("Missing values after cleaning:")
print(cleaned_user_details_df.isnull().sum())
# Out:
# Missing values after cleaning:
# Mal ID              0
# Username            0
# Gender              0
# Birthday            0
# Location            0
# Joined              0
# Days Watched        0
# Mean Score          0
# Watching            0
# Completed           0
# On Hold             0
# Dropped             0
# Plan to Watch       0
# Total Entries       0
# Rewatched           0
# Episodes Watched    0
# dtype: int64

# %%
#Check for duplicates

duplicates_user_details = cleaned_user_details_df.duplicated().sum()
print(f"Number of duplicate rows: {duplicates_user_details}")

#Display duplicate rows if any exist

if duplicates_user_details > 0:
    print("Duplicate rows found:")
    display(cleaned_user_details_df[cleaned_user_details_df.duplicated(keep=False)]) # Show all duplicate rows (including first occurrence)

# Remove duplicates if necessary

cleaned_user_details_df = cleaned_user_details_df.drop_duplicates()

# Verify removal

print(f"Number of duplicate rows after removal:{cleaned_user_details_df.duplicated().sum()}")
# Out:
# Number of duplicate rows: 0
# Number of duplicate rows after removal:0

# %%
cleaned_user_details_df.to_csv('cleaned_user_details_df.csv', index=False)

# %%
user_score_df = pd.read_csv("users-score-2023.csv")

# %%
user_score_df.head()
# Out:
#    user_id Username  anime_id             Anime Title  rating
# 0        1    Xinil        21               One Piece       9
# 1        1    Xinil        48             .hack//Sign       7
# 2        1    Xinil       320                  A Kite       5
# 3        1    Xinil        49        Aa! Megami-sama!       8
# 4        1    Xinil       304  Aa! Megami-sama! Movie       8

# %%
print(f"User Score Dataset contains {user_score_df.shape[0]} rows and {user_score_df.shape[1]}columns.")
# Out:
# User Score Dataset contains 24325191 rows and 5columns.

# %%
user_score_df.info(memory_usage='deep', show_counts=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 24325191 entries, 0 to 24325190
# Data columns (total 5 columns):
#  #   Column       Non-Null Count     Dtype
# ---  ------       --------------     -----
#  0   user_id      24325191 non-null  int64
#  1   Username     24324959 non-null  object
#  2   anime_id     24325191 non-null  int64
#  3   Anime Title  24325191 non-null  object
#  4   rating       24325191 non-null  int64
# dtypes: int64(3), object(2)
# memory usage: 3.5 GB

# %%
#Identify missing values using isnull()
print("Missing Values Count:\n", user_score_df.isnull().sum())

# Display rows with missing values
user_score_df[user_score_df.isnull().any(axis=1)]
# Out:
# Missing Values Count:
#  user_id          0
# Username       232
# anime_id         0
# Anime Title      0
# rating           0
# dtype: int64
#          user_id Username  anime_id  \
# 1571720    20930      NaN     52034
# 1571721    20930      NaN       299
# 1571722    20930      NaN       873
# 1571723    20930      NaN        48
# 1571724    20930      NaN       298
# ...          ...      ...       ...
# 1571947    20930      NaN     39617
# 1571948    20930      NaN     35507
# 1571949    20930      NaN       145
# 1571950    20930      NaN       516
# 1571951    20930      NaN       934
#
#                                              Anime Title  rating
# 1571720                                     "Oshi no Ko"       9
# 1571721                                .hack//Liminality       8
# 1571722                                     .hack//Roots       7
# 1571723                                      .hack//Sign       8
# ...

# %%
#Remove rows with missing values in the Username . Save this as a new variable called cleaned_user_score_df

cleaned_user_score_df = user_score_df.dropna(subset=['Username'])

#Verify if the process was completed by checking the number of remaining missing values

print("Missing values after cleaning:")
print(cleaned_user_score_df.isnull().sum())
# Out:
# Missing values after cleaning:
# user_id        0
# Username       0
# anime_id       0
# Anime Title    0
# rating         0
# dtype: int64

# %%
#Check for duplicates

duplicates_user_score = cleaned_user_score_df.duplicated().sum()
print(f"Number of duplicate rows: {duplicates_user_score}")

#Display duplicate rows if any exist

if duplicates_user_score > 0:
    print("Duplicate rows found:")
    display(cleaned_user_score_df[cleaned_user_score_df.duplicated(keep=False)]) # Show all duplicate rows (including first occurrence)

# Remove duplicates if necessary

cleaned_user_score_df = cleaned_user_score_df.drop_duplicates()

# Verify removal

print(f"Number of duplicate rows after removal:{cleaned_user_score_df.duplicated().sum()}")
# Out:
# Number of duplicate rows: 0
# Number of duplicate rows after removal:0

# %%
cleaned_user_score_df.to_csv('cleaned_user_score_df.csv', index=False)

# %%
#Numeric conversion for anime dataset

num_cols = ['Score', 'Rank', 'Scored By', 'Members']

for c in num_cols:
    cleaned_anime_df[c] = cleaned_anime_df[c].replace(['-', '?', 'Unknown'], np.nan)
    cleaned_anime_df[c + '_num'] = pd.to_numeric(cleaned_anime_df[c], errors='coerce')

#Episodes
cleaned_anime_df['Episodes'] = cleaned_anime_df['Episodes'].replace(['Unknown', '?', '-'], np.nan)
cleaned_anime_df['Episodes_num'] = pd.to_numeric(cleaned_anime_df['Episodes'], errors='coerce')

#Date conversion

#Aired
cleaned_anime_df['Aired_start'] = cleaned_anime_df['Aired'].str.split('to').str[0].str.strip()
cleaned_anime_df['Aired_start'] = cleaned_anime_df['Aired_start'].replace(['Unknown', '?', '-'], np.nan)
cleaned_anime_df['Aired_date'] = pd.to_datetime(cleaned_anime_df['Aired_start'], errors='coerce')
cleaned_anime_df['Aired_year'] = cleaned_anime_df['Aired_start'].str.extract(r'(\d{4})')
cleaned_anime_df['Aired_year'] = pd.to_numeric(cleaned_anime_df['Aired_year'], errors='coerce')

#Premiered
cleaned_anime_df['Premiered_season'] = cleaned_anime_df['Premiered'].str.split().str[0]
cleaned_anime_df['Premiered_year'] = pd.to_numeric(cleaned_anime_df['Premiered'].str.split().str[-1], errors='coerce')


#Categorical standardisation

cat_cols = ['Name', 'English name', 'Other name', 'Synopsis', 'Genres', 
            'Type', 'Status', 'Producers', 'Licensors', 'Studios', 
            'Source', 'Duration', 'Rating']

for c in cat_cols:
    cleaned_anime_df[c + '_cat'] = cleaned_anime_df[c].astype(str).str.strip().str.lower()


#Missing value handling

#Numeric: fill median
numeric_fill_cols = ['Score_num', 'Rank_num', 'Scored By_num', 'Episodes_num']

for c in numeric_fill_cols:
    median_val = cleaned_anime_df[c].median()
    cleaned_anime_df[c].fillna(median_val, inplace=True)

#Aired_year: fill mode
mode_aired_year = int(cleaned_anime_df['Aired_year'].mode()[0])
cleaned_anime_df['Aired_year'].fillna(mode_aired_year, inplace=True)

#Premiered_year: keep NaN (77% missing, realistic)
#Optionally, can fill 0 or mode if needed for specific analysis


#Missing % check

check_cols = numeric_fill_cols + ['Aired_date', 'Aired_year', 'Premiered_year']
missing_summary = cleaned_anime_df[check_cols].isna().mean() * 100
print("Missing % after cleaning:\n", missing_summary.round(2))


#Create missing flags

cleaned_anime_df['Premiered_year_missing'] = cleaned_anime_df['Premiered_year'].isna()
cleaned_anime_df['Aired_date_missing'] = cleaned_anime_df['Aired_date'].isna()

#Create missing flags

cleaned_anime_df['Premiered_year_missing'] = cleaned_anime_df['Premiered_year'].isna()
cleaned_anime_df['Aired_date_missing'] = cleaned_anime_df['Aired_date'].isna()


#Select columns for ready-to-analyse preview

preview_cols = [
    'anime_id', 'Name', 'Score_num', 'Rank_num', 'Scored By_num', 'Members_num',
    'Episodes_num', 'Aired_year', 'Premiered_season', 'Premiered_year',
    'Aired_date_missing', 'Premiered_year_missing',
    'Genres_cat', 'Type_cat', 'Status_cat', 'Studios_cat'
]


#Show sample ready-to-analyse dataset

ready_df = cleaned_anime_df[preview_cols]
ready_df.head(10)
# Out:
# Missing % after cleaning:
#  Score_num          0.00
# Rank_num           0.00
# Scored By_num      0.00
# Episodes_num       0.00
# Aired_date        19.33
# Aired_year         0.00
# Premiered_year    77.89
# dtype: float64
# C:\Users\aidam\AppData\Local\Temp\ipykernel_1980\1545090413.py:44: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   cleaned_anime_df[c].fillna(median_val, inplace=True)
# ...

# %%
#Numeric conversion for user score dataset
num_cols = ['rating', 'rating_num']
for col in num_cols:
    cleaned_user_score_df[col + '_num'] = pd.to_numeric(cleaned_user_score_df[col], errors='coerce')

# === Step 2: Categorical conversion ===
cat_cols = ['Username', 'Anime Title', 'Username_cat', 'Anime_Title_cat']
for col in cat_cols:
    cleaned_user_score_df[col + '_cat'] = cleaned_user_score_df[col].astype(str).str.lower().str.strip()

# === Step 3: Missing value flags (optional) ===
for col in num_cols + cat_cols:
    cleaned_user_score_df[col + '_missing'] = cleaned_user_score_df[col].isna()

# === Step 4: Quick check ===
print(cleaned_user_score_df.head(5))
# Out:
#    user_id Username  anime_id             Anime Title  rating  rating_num  \
# 0        1    Xinil        21               One Piece       9           9
# 1        1    Xinil        48             .hack//Sign       7           7
# 2        1    Xinil       320                  A Kite       5           5
# 3        1    Xinil        49        Aa! Megami-sama!       8           8
# 4        1    Xinil       304  Aa! Megami-sama! Movie       8           8
#
#   Username_cat         Anime_Title_cat  rating_num_num  \
# 0        xinil               one piece               9
# 1        xinil             .hack//sign               7
# 2        xinil                  a kite               5
# 3        xinil        aa! megami-sama!               8
# 4        xinil  aa! megami-sama! movie               8
#
#           Anime Title_cat Username_cat_cat     Anime_Title_cat_cat  \
# 0               one piece            xinil               one piece
# ...

# %%
#Numeric conversion for anime filter dataset

num_cols = ['Score','Ranked','Members','Watching','Completed','On-Hold','Dropped']
for c in num_cols:
    cleaned_anime_filter_df[c] = cleaned_anime_filter_df[c].replace(['-','?','Unknown'], np.nan)
    cleaned_anime_filter_df[c + '_num'] = pd.to_numeric(cleaned_anime_filter_df[c], errors='coerce')


#Date conversion

cleaned_anime_filter_df['Aired_start'] = cleaned_anime_filter_df['Aired'].str.split('to').str[0].str.strip()
cleaned_anime_filter_df['Aired_start'] = cleaned_anime_filter_df['Aired_start'].replace(['Unknown', '?', '-'], np.nan)
cleaned_anime_filter_df['Aired_date'] = pd.to_datetime(cleaned_anime_filter_df['Aired_start'], errors='coerce')

cleaned_anime_filter_df['Premiered_season'] = cleaned_anime_filter_df['Premiered'].str.split().str[0]
cleaned_anime_filter_df['Premiered_year'] = pd.to_numeric(cleaned_anime_filter_df['Premiered'].str.split().str[-1], errors='coerce')


#Categorical standardisation

cat_cols = ['Name','English name','Japanese name','Genres','Type','Producers','Licensors','Studios','Source','Duration','Rating']
for c in cat_cols:
    cleaned_anime_filter_df[c + '_cat'] = cleaned_anime_filter_df[c].astype(str).str.strip().str.lower()


#Missing flags for Aired & Premiered

cleaned_anime_filter_df['Aired_date_missing'] = cleaned_anime_filter_df['Aired_date'].isna()
cleaned_anime_filter_df['Premiered_year_missing'] = cleaned_anime_filter_df['Premiered_year'].isna()


#Ready-to-analyse preview

preview_cols = [
    'anime_id', 'Name', 'Score', 'Ranked', 'Members', 'Watching', 'Completed',
    'On-Hold', 'Dropped', 'Aired_date', 'Premiered_season', 'Premiered_year',
    'Aired_date_missing', 'Premiered_year_missing',
    'Genres_cat', 'Type_cat', 'Studios_cat'
]

ready_anime_filter_df = cleaned_anime_filter_df[preview_cols]

#Show sample
ready_anime_filter_df.head(10)
# Out:
#    anime_id                             Name  Score  Ranked  Members  \
# 0         1                     Cowboy Bebop   8.78    28.0  1251960
# 1         5  Cowboy Bebop: Tengoku no Tobira   8.39   159.0   273145
# 2         6                           Trigun   8.24   266.0   558913
# 3         7               Witch Hunter Robin   7.27  2481.0    94683
# 4         8                   Bouken Ou Beet   6.98  3710.0    13224
# 5        15                     Eyeshield 21   7.95   604.0   148259
# 6        16             Hachimitsu to Clover   8.06   468.0   214499
# 7        17       Hungry Heart: Wild Striker   7.59  1317.0    20470
# 8        18           Initial D Fourth Stage   8.15   360.0   117929
# 9        19                          Monster   8.76    30.0   614100
#
#    Watching  Completed  On-Hold  Dropped Aired_date Premiered_season  \
# 0    105808     718161    71513    26678 1998-04-03           Spring
# ...

# %%
# Numeric conversion for anime final dataset

num_cols = ['my_score','score','scored_by','popularity']
for c in num_cols:
    # Tukar ke numeric, errors -> NaN
    cleaned_anime_final_df[c + '_num'] = pd.to_numeric(cleaned_anime_final_df[c], errors='coerce')


# Categorical conversion (memory safe)

cat_cols = ['username','title','type','source','gender','genre']
for c in cat_cols:
    # Convert to category instead of full string
    cleaned_anime_final_df[c + '_cat'] = cleaned_anime_final_df[c].astype('category')


# Missing flags for numeric columns

for c in num_cols:
    cleaned_anime_final_df[c + '_missing'] = cleaned_anime_final_df[c].isna()


# Preview (first 10 rows)

preview_cols = [col + '_num' for col in num_cols] + \
               [col + '_cat' for col in cat_cols] + \
               [col + '_missing' for col in num_cols]

ready_df = cleaned_anime_final_df[preview_cols]
ready_df.head(10)
# Out:
#    my_score_num  score_num  scored_by_num  popularity_num username_cat  \
# 0             9       8.54         423868              35     karthiga
# 1             7       7.53         175388             188     karthiga
# 2             7       7.77          33244            1291     karthiga
# 3             7       7.77         167968             222     karthiga
# 4             7       7.26           9663            2490     karthiga
# 5             7       7.85          59911             623     karthiga
# 6             6       8.21         121898             292     karthiga
# 7             6       7.78           6598            3045     karthiga
# 8             8       7.90         181978             141     karthiga
# 9            10       7.90         433097              18     karthiga
#
#            title_cat type_cat source_cat gender_cat  \
# 0          One Piece       TV      Manga     Female
# 1            Chobits       TV      Manga     Female
# ...

# %%
# Numeric conversion for user details dataset

num_cols = ['Days Watched','Mean Score','Watching','Completed','On Hold','Dropped','Plan to Watch','Total Entries','Rewatched','Episodes Watched']
for c in num_cols:
    cleaned_user_details_df[c + '_num'] = pd.to_numeric(cleaned_user_details_df[c], errors='coerce')

# Categorical conversion

cat_cols = ['Username','Gender','Location']
for c in cat_cols:
    cleaned_user_details_df[c + '_cat'] = cleaned_user_details_df[c].astype(str).str.strip().str.lower()

# Date conversion

cleaned_user_details_df['Birthday_date'] = pd.to_datetime(cleaned_user_details_df['Birthday'], errors='coerce')
cleaned_user_details_df['Joined_date'] = pd.to_datetime(cleaned_user_details_df['Joined'], errors='coerce')

# Missing value flags

cleaned_user_details_df['Birthday_missing'] = cleaned_user_details_df['Birthday_date'].isna()
cleaned_user_details_df['Joined_missing'] = cleaned_user_details_df['Joined_date'].isna()


# Select ready-to-analyse columns

preview_cols = [
    'Username', 'Gender', 'Location',
    'Days Watched_num','Mean Score_num','Watching_num','Completed_num',
    'On Hold_num','Dropped_num','Plan to Watch_num','Total Entries_num',
    'Rewatched_num','Episodes Watched_num',
    'Birthday_date','Joined_date',
    'Birthday_missing','Joined_missing'
]


# Show sample ready-to-analyse dataset

ready_user_details_df = cleaned_user_details_df[preview_cols]
ready_user_details_df.head(10)
# Out:
#        Username Gender                                          Location  \
# 0         Xinil   Male                                        California
# 5        vondur   Male                                    Bergen, Norway
# 11       Hiromi   Male                                       Calgary, AB
# 16       Achtor   Male                                     Paris, France
# 23     luffykun   Male                                    London,England
# 26        hazte   Male                               Lule&aring;, Sweden
# 30  DanskiJonez   Male                                   Ontario, Canada
# 35        Holzy   Male  Locked up in Shuuka basement working on cards :p
# 39        Fador   Male                                  Tampere, Finland
# 41  Arinohyoshi   Male                                     Finland, Pori
#
#     Days Watched_num  Mean Score_num  Watching_num  Completed_num  \
# 0              142.3            7.37           1.0          233.0
# ...

# %%
# Numeric conversion for user_filtered dataset
num_cols = ['rating']
for col in num_cols:
    cleaned_user_filtered_df[col + '_num'] = pd.to_numeric(cleaned_user_filtered_df[col], errors='coerce')

# Missing value flags
for col in num_cols:
    cleaned_user_filtered_df[col + '_missing'] = cleaned_user_filtered_df[col].isna()

#Quick check
print(cleaned_user_filtered_df.head(5))
# Out:
#    user_id  anime_id  rating  rating_num  rating_missing
# 0        0        67       9           9           False
# 1        0      6702       7           7           False
# 2        0       242      10          10           False
# 3        0      4898       0           0           False
# 4        0        21      10          10           False

# %%
#Merge cleaned_anime_df + cleaned_anime_filter_df
anime_merged_df = pd.merge(
    cleaned_anime_df,
    cleaned_anime_filter_df[['anime_id', 'Watching_num', 'Completed_num', 'On-Hold_num', 'Dropped_num', 'Favorites', 'Ranked_num']],
    on='anime_id',
    how='left'
)


# Create missing flags only for columns that exist
flag_cols = [c for c in ['Watching_num', 'Completed_num', 'On-Hold_num', 'Dropped_num', 'Favorites', 'Ranked_num'] if c in anime_merged_df.columns]

for col in flag_cols:
    anime_merged_df[col + '_missing'] = anime_merged_df[col].isna()

anime_merged_df.head(5)
# Out:
#    anime_id                             Name             English name  \
# 0         1                     Cowboy Bebop             Cowboy Bebop
# 1         5  Cowboy Bebop: Tengoku no Tobira  Cowboy Bebop: The Movie
# 2         6                           Trigun                   Trigun
# 3         7               Witch Hunter Robin       Witch Hunter Robin
# 4         8                   Bouken Ou Beet   Beet the Vandel Buster
#
#                          Other name Score  \
# 0                         カウボーイビバップ  8.75
# 1                    カウボーイビバップ 天国の扉  8.38
# 2                             トライガン  8.22
# 3  Witch Hunter ROBIN (ウイッチハンターロビン)  7.25
# 4                            冒険王ビィト  6.94
#
#                                  Genres  \
# 0         Action, Award Winning, Sci-Fi
# 1                        Action, Sci-Fi
# 2             Action, Adventure, Sci-Fi
# 3  Action, Drama, Mystery, Supernatural
# 4      Adventure, Fantasy, Supernatural
#
# ...

# %%
#Aggregate user scores per anime

anime_rating_agg = cleaned_user_score_df.groupby('anime_id')['rating'].mean().reset_index()
anime_rating_agg.rename(columns={'rating':'avg_rating'}, inplace=True)

#Merge dengan anime dataset
anime_merged_df2 = pd.merge(
    anime_merged_df,
    anime_rating_agg,
    on='anime_id',
    how='left'
)

#Flag missing average ratings
anime_merged_df2['avg_rating_missing'] = anime_merged_df2['avg_rating'].isna()

#Quick check
anime_merged_df2.head()
# Out:
#    anime_id                             Name             English name  \
# 0         1                     Cowboy Bebop             Cowboy Bebop
# 1         5  Cowboy Bebop: Tengoku no Tobira  Cowboy Bebop: The Movie
# 2         6                           Trigun                   Trigun
# 3         7               Witch Hunter Robin       Witch Hunter Robin
# 4         8                   Bouken Ou Beet   Beet the Vandel Buster
#
#                          Other name Score  \
# 0                         カウボーイビバップ  8.75
# 1                    カウボーイビバップ 天国の扉  8.38
# 2                             トライガン  8.22
# 3  Witch Hunter ROBIN (ウイッチハンターロビン)  7.25
# 4                            冒険王ビィト  6.94
#
#                                  Genres  \
# 0         Action, Award Winning, Sci-Fi
# 1                        Action, Sci-Fi
# 2             Action, Adventure, Sci-Fi
# 3  Action, Drama, Mystery, Supernatural
# 4      Adventure, Fantasy, Supernatural
#
# ...

# %%
#Columns identifier yang nak exclude dari summary
id_cols = ['user_id', 'anime_id']

#Tentukan jumlah sample row
sample_size = 100_000

#Ambil sample, handle dataframe kecil
n_sample = min(sample_size, len(cleaned_anime_filter_df))
anime_filter_sample_df = cleaned_anime_filter_df.sample(n=n_sample, random_state=42)

#Ambil numeric columns sahaja, exclude id_cols
numerical_columns = anime_filter_sample_df.drop(columns=id_cols, errors='ignore').select_dtypes(include='number')

#Buat summary
numerical_summary = numerical_columns.describe()

print(f"Numerical summary (sample {n_sample} rows):\n", numerical_summary)
# Out:
# Numerical summary (sample 13229 rows):
#                Score        Ranked    Popularity       Members      Favorites  \
# count  13229.000000  13229.000000  13229.000000  1.322900e+04   13229.000000
# mean       6.549368   6829.241364   7463.690906  4.505973e+04     601.686900
# std        0.822849   4168.674693   4487.187134  1.427203e+05    4672.643973
# min        1.850000      1.000000      1.000000  2.000000e+02       0.000000
# 25%        6.120000   3309.000000   3392.000000  6.410000e+02       1.000000
# 50%        6.510000   6614.000000   7517.000000  3.389000e+03       5.000000
# 75%        7.080000   9941.000000  11514.000000  2.322200e+04      51.000000
# max        9.190000  15780.000000  17500.000000  2.589552e+06  183914.000000
#
#             Watching     Completed        On-Hold       Dropped     Score_num  \
# count   13229.000000  1.322900e+04   13229.000000   13229.00000  13229.000000
# ...

# %%
#Columns identifier yang nak exclude dari summary
id_cols = ['user_id', 'anime_id']

#Tentukan jumlah sample row
sample_size = 100_000

#Ambil sample, handle dataframe kecil
n_sample = min(sample_size, len(cleaned_anime_final_df))
anime_final_sample_df = cleaned_anime_final_df.sample(n=n_sample, random_state=42)

#Ambil numeric columns sahaja, exclude id_cols
numerical_columns = anime_final_sample_df.drop(columns=id_cols, errors='ignore').select_dtypes(include='number')

#Buat summary
numerical_summary = numerical_columns.describe()

print(f"Numerical summary (sample {n_sample} rows):\n", numerical_summary)
# Out:
# Numerical summary (sample 100000 rows):
#             my_score          score     scored_by           rank  \
# count  100000.00000  100000.000000  1.000000e+05  100000.000000
# mean        4.60950       7.546700  1.108582e+05    2051.184110
# std         3.91812       0.715576  1.477730e+05    1975.667802
# min         0.00000       1.900000  2.000000e+02       1.000000
# 25%         0.00000       7.140000  1.895100e+04     502.000000
# 50%         6.00000       7.570000  5.628300e+04    1420.000000
# 75%         8.00000       8.040000  1.417620e+05    3046.250000
# max        10.00000       9.250000  1.009477e+06    9527.000000
#
#           popularity  my_score_num      score_num  scored_by_num  \
# count  100000.000000  100000.00000  100000.000000   1.000000e+05
# mean     1269.056940       4.60950       7.546700   1.108582e+05
# std      1485.458907       3.91812       0.715576   1.477730e+05
# min         1.000000       0.00000       1.900000   2.000000e+02
# ...

# %%
# Numerical Summary for cleaned_user_details_df
id_cols = ['Mal ID']  # drop identifier/helper columns

numerical_data = cleaned_user_details_df.drop(columns=id_cols, errors='ignore')
numerical_columns = numerical_data.select_dtypes(include='number')
numerical_summary = numerical_columns.describe()

print("Numerical Summary:\n", numerical_summary)
# Out:
# Numerical Summary:
#          Days Watched     Mean Score       Watching      Completed  \
# count  115457.000000  115457.000000  115457.000000  115457.000000
# mean       51.830104       6.794457       9.611007     139.579982
# std       319.627641       3.066103      27.508248     258.951629
# min         0.000000       0.000000       0.000000       0.000000
# 25%         4.600000       7.000000       1.000000       6.000000
# 50%        26.400000       7.840000       4.000000      50.000000
# 75%        69.000000       8.500000      10.000000     165.000000
# max    105338.600000      10.000000    2934.000000   11643.000000
#
#              On Hold        Dropped  Plan to Watch  Total Entries  \
# count  115457.000000  115457.000000  115457.000000  115457.000000
# mean        7.368076       9.059286      39.435495     205.057571
# std        30.429667      37.598057     139.253123     372.109748
# min         0.000000       0.000000       0.000000       0.000000
# ...

# %%
# Letakkan semua dataset dalam satu dict
datasets = {
    "anime": cleaned_anime_df,
    "user_score": cleaned_user_score_df,
    "user_filter": cleaned_user_filtered_df,
    "anime_filter": cleaned_anime_filter_df,
    "anime_final": cleaned_anime_final_df,
    "user_details": cleaned_user_details_df
}

# Loop untuk Explorecategorical variable
for name, df in datasets.items():
    print(f"\n--- Categorical EDA for {name} ---")
    
    # STEP 1: Identify categorical columns
    categorical_columns = df.select_dtypes(include="object").columns
    print("Frequency distribution for categorical variables:")
    
    # STEP 2 & 3: Loop dan display absolute counts
    for col in categorical_columns:
        print(f"\nColumn: {col}")
        print(df[col].value_counts())
# Out:
# --- Categorical EDA for anime ---
# Frequency distribution for categorical variables:
#
# Column: Name
# Name
# Utopia               2
# Souseiki             2
# Azur Lane            2
# Awakening            2
# Tensura × Genyoha    1
#                     ..
# Texhnolyze           1
# Trinity Blood        1
# Yakitate!! Japan     1
# Zipang               1
# Bouken Ou Beet       1
# Name: count, Length: 24901, dtype: int64
#
# Column: English name
# English name
# UNKNOWN                       14577
# Promise                           5
# Spirit Guardians                  5
# Cyborg 009                        4
# Meow Meow Japanese History        4
#                               ...
# Mirage Of The Past                1
# Albino                            1
# Original (2021)                   1
# Monologue                         1
# Blaze                             1
# Name: count, Length: 10134, dtype: int64
#
# Column: Other name
# Other name
# UNKNOWN           128
# ...

# %%
# Merge user scores dengan anime info untuk tahun
user_score_with_year = pd.merge(
    cleaned_user_score_df,
    cleaned_anime_df[['anime_id', 'Premiered_year']],
    on='anime_id',
    how='left'
)

# Group by year untuk total rating
engagement_by_year = user_score_with_year.groupby('Premiered_year')['rating'].count().reset_index()
engagement_by_year.rename(columns={'rating':'total_ratings'}, inplace=True)

all_years = pd.DataFrame({'Premiered_year': range(2000, 2024)})

# Plot
plt.figure(figsize=(10,5))
plt.plot(engagement_by_year['Premiered_year'], engagement_by_year['total_ratings'], marker='o', linestyle='-')
plt.xlabel("Year")
plt.ylabel("Total Ratings / Engagement")
plt.title("Trend of User Engagement")
plt.xticks(rotation=45)
plt.grid(True)
plt.show()

# %%
# Explode genres supaya satu row = satu genre
genre_df = cleaned_anime_df[['Premiered_year', 'Genres_cat']].copy()
genre_df['Genres_list'] = genre_df['Genres_cat'].str.split(', ')
genre_df = genre_df.explode('Genres_list')

# Group by year + genre
top_genres_year = genre_df.groupby(['Premiered_year', 'Genres_list']).size().reset_index(name='count')

# Contoh plot bar chart untuk satu tahun, atau line chart untuk trend
# Untuk simplicity, kita ambik top 5 genres per year
import seaborn as sns

plt.figure(figsize=(12,6))
sns.lineplot(
    data=top_genres_year,
    x='Premiered_year',
    y='count',
    hue='Genres_list',
    estimator='sum',
    ci=None
)
plt.title("Trend of Top Anime Genres")
plt.ylabel("Number of Anime")
plt.xlabel("Year")
plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left')
plt.show()
# Out:
# C:\Users\aidam\AppData\Local\Temp\ipykernel_1980\3564141385.py:14: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=None` for the same effect.
#
#   sns.lineplot(

# %%
# Merge user details dengan anime info
completed_with_year = pd.merge(
    cleaned_user_details_df,
    cleaned_anime_df[['anime_id', 'Premiered_year']],
    left_on='Mal ID',   # pastikan user_id align
    right_on='anime_id',  # kalau perlu adjust join
    how='left'
)

# Aggregate total completed per year
completed_by_year = completed_with_year.groupby('Premiered_year')['Completed_num'].sum().reset_index()

# Plot
plt.figure(figsize=(10,5))
plt.plot(completed_by_year['Premiered_year'], completed_by_year['Completed_num'], marker='o', linestyle='-')
plt.xlabel("Year")
plt.ylabel("Total Completed Episodes")
plt.title("Trend of Completed Anime Episodes")
plt.xticks(rotation=45)
plt.grid(True)
plt.show()

# %%
# Prepare genre-year table
anime_genres_year = cleaned_anime_filter_df[['Premiered_year', 'Genres_cat']].copy()
anime_genres_year['Genres_cat'] = anime_genres_year['Genres_cat'].str.split(',')
anime_genres_year = anime_genres_year.explode('Genres_cat')

# Group by year + genre
genre_year_counts = anime_genres_year.groupby(['Premiered_year', 'Genres_cat']).size().reset_index(name='count')
genre_year_pivot = genre_year_counts.pivot(index='Premiered_year', columns='Genres_cat', values='count').fillna(0)

# Plot stacked area
genre_year_pivot.plot(
    kind='area',
    stacked=True,
    figsize=(12,6),
    cmap='tab20'
)
plt.xlabel("Year")
plt.ylabel("Number of Anime")
plt.title("Genre Popularity Over Time")
plt.legend(loc='upper left', bbox_to_anchor=(1,1))
plt.tight_layout()
plt.show()
# Out:
# C:\Users\aidam\AppData\Local\Temp\ipykernel_1980\3517575536.py:21: UserWarning: Tight layout not applied. The bottom and top margins cannot be made large enough to accommodate all Axes decorations.
#   plt.tight_layout()

# %%
plt.figure(figsize=(8,5))
sns.histplot(cleaned_user_score_df['rating'], bins=20, kde=True, color='green')
plt.xlabel("User Rating")
plt.ylabel("Frequency")
plt.title("Distribution of User Ratings")
plt.show()
